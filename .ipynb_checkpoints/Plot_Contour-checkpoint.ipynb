# %% [markdown]
# ## Library import

# %%
import pandas as pd
import random
import os
import numpy as np
from Bio import SeqIO
import matplotlib.pyplot as plt
from operator import itemgetter 
from matplotlib import pyplot
from collections import Counter

SMALL_SIZE = 8
MEDIUM_SIZE = 16
BIGGER_SIZE = 20
import matplotlib.patches as patches
plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=BIGGER_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [markdown]
# # Contour line - length > 16

# %% [markdown]
# ## Relative importance x3

# %%
cors_mfold = np.load('contour/x3_longer.npy')
measure=cors_mfold

fig = plt.figure(figsize=(8, 6))
xdata = np.linspace(0,0.1,40)
ydata = np.linspace(0,0.1,40)
cntr = plt.contourf(xdata, ydata, measure, levels=15, cmap="RdBu_r")
plt.colorbar(cntr)
    
plt.scatter(0.02, 0.005, s=150, marker='o', edgecolors='yellow', facecolors='yellow')
plt.scatter(0.02, 0, s=150, marker='o', edgecolors='gray', facecolors='gray')
plt.scatter(0, 0.04, s=150, marker='o', edgecolors='black', facecolors='black')

plt.text(0.02, 0.005, "(0.72)", fontsize=16, fontweight='bold', ha='left', va='top')
plt.text(0.02-0.004, 0, "(0.71)", fontsize=16, fontweight='bold', ha='right', va='bottom')
plt.text(0, 0.04, "(0.32)", fontsize=16, fontweight='bold', ha='left', va='bottom')
    
# plt.ylabel(r'Secondary Structure ($\beta$)')
plt.ylabel(r'Off-target Gibbs Energy ($\beta$)')
plt.xlabel(r'On-target Gibbs Energy ($\alpha$)')
Fig_path = './fig'

# %% [markdown]
# ## Relative importance x2

# %%
cors_mfold = np.load('contour/x2_longer.npy')
measure=cors_mfold
xdata = np.linspace(0,5,50)
ydata = np.linspace(0,200,100)

fig = plt.figure(figsize=(8, 6))

cntr = plt.contourf(xdata, ydata, measure, levels=15, cmap="RdBu_r")
plt.colorbar(cntr)

plt.scatter(4.58, 182, s=150, marker='o', edgecolors='yellow', facecolors='yellow')
plt.scatter(0, 22.53, s=150, marker='o', edgecolors='gray', facecolors='gray')
plt.scatter(0.99, 0, s=150, marker='o', edgecolors='black', facecolors='black')

plt.text(4.58, 182-1, "(0.72)", fontsize=16, fontweight='bold', ha='left', va='top')
plt.text(0, 22.53-1, "(0.32)", fontsize=16, fontweight='bold', ha='left', va='bottom')
plt.text(0.99, 0+1, "(0.63)", fontsize=16, fontweight='bold', ha='left', va='bottom')

plt.ylabel(r'Secondary Structure ($\beta$)')
plt.xlabel(r'On-target Gibbs Energy ($\alpha$)')
Fig_path = './fig'

# %% [markdown]
# ## Relative importance x1

# %%
cors_mfold = np.load('contour/x1_longer.npy')
measure=cors_mfold
xdata = np.linspace(0,2,20)
ydata = np.linspace(0,80,40)

# %%
fig = plt.figure(figsize=(8, 6))

cntr = plt.contourf(xdata, ydata, measure, levels=15, cmap="RdBu_r")
plt.colorbar(cntr)

plt.scatter(0.18, 40, s=150, marker='o', edgecolors='yellow', facecolors='yellow')
plt.scatter(0, 43, s=150, marker='o', edgecolors='gray', facecolors='gray')
plt.scatter(0.92, 0, s=150, marker='o', edgecolors='black', facecolors='black')

plt.text(0.22, 40-1, "(0.72)", fontsize=16, fontweight='bold', ha='left', va='top')
plt.text(0, 43-1, "(0.71)", fontsize=16, fontweight='bold', ha='left', va='bottom')
plt.text(1.00, 0+1, "(0.63)", fontsize=16, fontweight='bold', ha='left', va='bottom')

plt.ylabel(r'Secondary Structure ($\beta$)')
plt.xlabel(r'Off-target Gibbs Energy ($\alpha$)')
Fig_path = './fig'

# %% [markdown]
# # Contour line - length > 16

# %% [markdown]
# ## Relative importance x3

# %%
cors_mfold = np.load('contour/x3_all.npy')

measure=cors_mfold

xdata = np.linspace(0,0.1,40)
ydata = np.linspace(0,0.1,40)
fig = plt.figure(figsize=(8, 6))


cntr = plt.contourf(xdata, ydata, measure, levels=15, cmap="RdBu_r")
plt.colorbar(cntr)

plt.scatter(0.02, 0.01, s=150, marker='o', edgecolors='yellow', facecolors='yellow')
plt.scatter(0.020, 0, s=150, marker='o', edgecolors='gray', facecolors='gray')
plt.scatter(0, 0.015, s=150, marker='o', edgecolors='black', facecolors='black')

plt.text(0.02, 0.01, "(0.57)", fontsize=16, fontweight='bold', ha='left', va='top')
plt.text(0.020, 0, "(0.55)", fontsize=16, fontweight='bold', ha='left', va='bottom')
plt.text(0, 0.015, "(0.41)", fontsize=16, fontweight='bold', ha='left', va='bottom')

plt.ylabel(r'Off-target Gibbs Energy ($\beta$)')
plt.xlabel(r'On-target Gibbs Energy ($\alpha$)')
    

Fig_path = './fig'

# %% [markdown]
# ## Relative importance x2

# %%
cors_mfold = np.load('contour/x2_all.npy')

measure=cors_mfold
xdata = np.linspace(0,5,50)
ydata = np.linspace(0,80,40)
fig = plt.figure(figsize=(8, 6))

cntr = plt.contourf(xdata, ydata, measure, levels=15, cmap="RdBu_r")
plt.colorbar(cntr)

plt.scatter(1.92, 73, s=150, marker='o', edgecolors='yellow', facecolors='yellow')
plt.scatter(0, 64, s=150, marker='o', edgecolors='gray', facecolors='gray')
plt.scatter(2.69, 0, s=150, marker='o', edgecolors='black', facecolors='black')

plt.text(1.92, 73+1, "(0.57)", fontsize=16, fontweight='bold', ha='left', va='bottom')
plt.text(0, 64, "(0.41)", fontsize=16, fontweight='bold', ha='left', va='bottom')
plt.text(2.69, 0+1, "(0.36)", fontsize=16, fontweight='bold', ha='left', va='bottom')
    
plt.ylabel(r'Secondary Structure ($\beta$)')
plt.xlabel(r'On-target Gibbs Energy ($\alpha$)')

Fig_path = './fig'

# %% [markdown]
# ## Relative importance x1

# %%
cors_mfold = np.load('contour/x1_all.npy')

measure=cors_mfold
xdata = np.linspace(0,2,20)
ydata = np.linspace(0,80,40)
fig = plt.figure(figsize=(8, 6))


cntr = plt.contourf(xdata, ydata, measure, levels=15, cmap="RdBu_r")
plt.colorbar(cntr)

plt.scatter(0.52, 38, s=150, marker='o', edgecolors='yellow', facecolors='yellow')
plt.scatter(0, 49, s=150, marker='o', edgecolors='gray', facecolors='gray')
plt.scatter(0.37, 0, s=150, marker='o', edgecolors='black', facecolors='black')

plt.text(0.52, 38+1, "(0.57)", fontsize=16, fontweight='bold', ha='left', va='bottom')
plt.text(0, 49, "(0.55)", fontsize=16, fontweight='bold', ha='left', va='bottom')
plt.text(0.37, 0+1, "(0.36)", fontsize=16, fontweight='bold', ha='left', va='bottom')
    
plt.ylabel(r'Secondary Structure ($\beta$)')
plt.xlabel(r'Off-target Gibbs Energy ($\alpha$)')

Fig_path = './fig'
